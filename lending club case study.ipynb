# %%
#importing all the important libraries like numpy. pandas, matlplolib, and warnings to keep notebook clean

import numpy as np   
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# to suppress warnings

import warnings   
warnings.filterwarnings("ignore")

# %%
#notebook setting to display all the rowns and columns to have better clearity on the data.

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.expand_frame_repr', False)

# %%
# importing loan.csv
LoanData = pd.read_csv("loan.csv")
# displaying the records to check the data
LoanData
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment grade sub_grade                   emp_title emp_length home_ownership  annual_inc verification_status issue_d  loan_status pymnt_plan                                                url                                               desc             purpose                      title zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  mths_since_last_major_derog  policy_code application_type  annual_inc_joint  dti_joint  verification_status_joint  acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  o
# ...

# %%
# Removing duplicate rows if any
LoanData=LoanData.drop_duplicates()

# %%
#checking the rows and columns of the raw dataset
LoanData.shape
# Out:
# (39717, 111)

# %%
# checking descriptional statistical values
LoanData.describe(include='all')
# Out:
#                   id     member_id     loan_amnt   funded_amnt  funded_amnt_inv        term int_rate   installment  grade sub_grade emp_title emp_length home_ownership    annual_inc verification_status issue_d loan_status pymnt_plan                                                url   desc             purpose               title zip_code addr_state           dti   delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  mths_since_last_record      open_acc       pub_rec      revol_bal revol_util     total_acc initial_list_status     out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  mths_since_last_major_derog  policy_code application_type  annual_inc_joint  dti_joint  verification_status_joint  acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  open_il_24m 
# ...

# %%
# displaying the metadata information of loan data dataset
LoanData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.9+ MB

# %%
# checking the target columns unique values
LoanData['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Charged Off', 'Current'], dtype=object)

# %%
LoanData.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit'], dtype='object', length=111)

# %%
LoanData.shape
# Out:
# (39717, 111)

# %%
#filling missing values with median values

LoanData.fillna(LoanData['loan_amnt'].median(),inplace = True)

# %%
# Checking the numeric variables of the dataframes
LoanData.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  funded_amnt_inv   installment    annual_inc           dti   delinq_2yrs  inq_last_6mths  mths_since_last_delinq  mths_since_last_record      open_acc       pub_rec      revol_bal     total_acc     out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee    recoveries  collection_recovery_fee  last_pymnt_amnt  collections_12_mths_ex_med  mths_since_last_major_derog  policy_code  annual_inc_joint  dti_joint  verification_status_joint  acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim   inq_fi  total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  mths_since_recent_
# ...

# %%
#checking how many null values are present in each of the columns

#creating a function to find null values for the dataframe
def null_values(df):
    return round((df.isnull().sum()*100/len(df)).sort_values(ascending = False),2)
    
null_values(LoanData)
# Out:
# id                                0.0
# total_rev_hi_lim                  0.0
# mo_sin_old_rev_tl_op              0.0
# mo_sin_old_il_acct                0.0
# delinq_amnt                       0.0
# chargeoff_within_12_mths          0.0
# bc_util                           0.0
# bc_open_to_buy                    0.0
# avg_cur_bal                       0.0
# acc_open_past_24mths              0.0
# inq_last_12m                      0.0
# total_cu_tl                       0.0
# inq_fi                            0.0
# all_util                          0.0
# mo_sin_rcnt_tl                    0.0
# max_bal_bc                        0.0
# open_rv_24m                       0.0
# open_rv_12m                       0.0
# il_util                           0.0
# total_bal_il                      0.0
# mths_since_rcnt_il                0.0
# open_il_24m                       0.0
# open_il_12m                       0.0
# open_il_6m                        0.0
# open_acc_6m                       0.0
# ...

# %%
#creating a variable null_col_50 for storing null columns having missing values more than 50%

null_col_50 = null_values(LoanData)[null_values(LoanData)>50]
#revieving null_col_50

print(null_col_50)
print()
print("Num of columns having missing values more than 50% :",len(null_col_50))
# Out:
# Series([], dtype: float64)
#
# Num of columns having missing values more than 50% : 0

# %%
null_col_50.index  # Will drop all these columns
# Out:
# Index([], dtype='object')

# %%
# Now lets drop all the columns having missing values more than 50% that is 41 columns
#LoanData.drop(columns = null_col_50.index, inplace = True)
LoanData = LoanData.loc[:,LoanData.isnull().mean()<=0.5]
LoanData.shape
# Out:
# (39717, 111)

# %% [markdown]
# Data Cleaning

# %%
# listing the null values columns having more than 30%

empty = LoanData.isnull().sum()
empty = empty[empty.values > (1*len(empty))]
len(empty)
# Out:
# 0

# %% [markdown]
# # Seems likes there are 61 columns with more that 100% null values, we can remove those columns for better analysis.

# %%
print(empty)
# Out:
# Series([], dtype: int64)

# %%
empty = list(empty[empty.values>=1].index)
LoanData.drop(labels=empty,axis=1,inplace=True)

# %%
# now we will deal with null values more than 15% 

null_col_15 = null_values(LoanData)[null_values(LoanData)>15]

# %%
#now we have 50 column left with less null values. we can now check for missing values.
LoanData.shape
# Out:
# (39717, 111)

# %%
empty = LoanData.isnull().sum()
empty = empty[empty.values > (0.9*len(empty))]
len(empty)
# Out:
# 0

# %% [markdown]
# We again have 4 columns with 90% null values. we can remove them as well.

# %%
empty = list(empty[empty.values>=1].index)
LoanData.drop(labels=empty,axis=1,inplace=True)

# %%
LoanData.shape
# Out:
# (39717, 111)

# %%
#checking the percentage of null values in column
LoanData.isnull().sum()/len(LoanData)*100
# Out:
# id                                0.0
# member_id                         0.0
# loan_amnt                         0.0
# funded_amnt                       0.0
# funded_amnt_inv                   0.0
# term                              0.0
# int_rate                          0.0
# installment                       0.0
# grade                             0.0
# sub_grade                         0.0
# emp_title                         0.0
# emp_length                        0.0
# home_ownership                    0.0
# annual_inc                        0.0
# verification_status               0.0
# issue_d                           0.0
# loan_status                       0.0
# pymnt_plan                        0.0
# url                               0.0
# desc                              0.0
# purpose                           0.0
# title                             0.0
# zip_code                          0.0
# addr_state                        0.0
# dti                               0.0
# ...

# %% [markdown]
# Checking for rows with more than 30% null values.

# %%
emptyrow=LoanData.isnull().sum(axis=1)
emptyrow=list(emptyrow[emptyrow.values>=0.3*len(LoanData)].index)
len(emptyrow)
# Out:
# 0

# %% [markdown]
# As non of the rows having more that 30% null values so elimination needed.

# %%
LoanData.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit'], dtype='object', length=111)

# %%
LoanData.isnull().sum()/len(LoanData)*100
# Out:
# id                                0.0
# member_id                         0.0
# loan_amnt                         0.0
# funded_amnt                       0.0
# funded_amnt_inv                   0.0
# term                              0.0
# int_rate                          0.0
# installment                       0.0
# grade                             0.0
# sub_grade                         0.0
# emp_title                         0.0
# emp_length                        0.0
# home_ownership                    0.0
# annual_inc                        0.0
# verification_status               0.0
# issue_d                           0.0
# loan_status                       0.0
# pymnt_plan                        0.0
# url                               0.0
# desc                              0.0
# purpose                           0.0
# title                             0.0
# zip_code                          0.0
# addr_state                        0.0
# dti                               0.0
# ...

# %%
#As title, last_credit_pull_d, tax_liens has very few missing values so will update them with median value
values=LoanData['title'].mode()
LoanData.loc[LoanData['title'].isnull(),'title']=values

# %%
values=LoanData['last_credit_pull_d'].mode()

LoanData.loc[LoanData['last_credit_pull_d'].isnull(),'last_credit_pull_d']=values

# %%
values=LoanData['tax_liens'].mode()

LoanData.loc[LoanData['tax_liens'].isnull(),'tax_liens']=values

# %%
LoanData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.9+ MB

# %%
LoanData['annual_inc'].describe()
# Out:
# count    3.971700e+04
# mean     6.896893e+04
# std      6.379377e+04
# min      4.000000e+03
# 25%      4.040400e+04
# 50%      5.900000e+04
# 75%      8.230000e+04
# max      6.000000e+06
# Name: annual_inc, dtype: float64

# %%
#Converting required categoical columns from Object to categorical 

p_catgorical_col = ['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment', 
                    'grade', 'sub_grade', 'home_ownership', 'annual_inc', 'verification_status', 'issue_d', 'loan_status', 
                    'pymnt_plan', 'url', 'purpose', 'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
                    'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'total_acc', 'initial_list_status', 'out_prncp', 
                    'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee',
                    'recoveries', 'collection_recovery_fee', 'last_pymnt_amnt', 'last_credit_pull_d', 'policy_code', 
                    'application_type', 'acc_now_delinq', 'delinq_amnt', 'tax_liens']

for col in p_catgorical_col:
    LoanData[col] =pd.Categorical(LoanData[col])

# %% [markdown]
# # Function to plot Univariate, Bivariate, Point plot

# %%
# Creating a function to find if the column is categorical or numerical 

def data_type(dataset,col):
    if dataset[col].dtype == np.int64 or dataset[col].dtype == np.float64:
        return "numerical"
    if dataset[col].dtype == "category":
        return "categorical"
    
# Creating a function "univariate" to perform analysis one single variable with respect to target variable

def univariate(dataset,col,target_col,ylog=False,x_label_angle=False,h_layout=True):
    if data_type(dataset,col) == "numerical":
        sns.distplot(dataset[col],hist=False)
        
        
    elif data_type(dataset,col) == "categorical":
        val_count = dataset[col].value_counts()
        df1 = pd.DataFrame({col: val_count.index,'count': val_count.values})
        
        
        target_1_percentage = dataset[[col, target_col]].groupby([col],as_index=False).mean()
        target_1_percentage[target_col] = target_1_percentage[target_col]*100
        target_1_percentage.sort_values(by=target_col,inplace = True)
        
        
# If the plot is not readable, use the log scale

        if(h_layout):
            fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15,7))
        else:
            fig, (ax1, ax2) = plt.subplots(nrows=2, figsize=(25,35))
              
        
# 1. Subplot 1: Count plot of the column
        
        s = sns.countplot(ax=ax1, x=col, data=dataset, hue=target_col)
        ax1.set_title(col, fontsize = 20)
        ax1.legend(['loan_amnt','annual_inc'])
        ax1.set_xlabel(col,fontdict={'fontsize' : 15, 'fontweight' : 3})
        
        if(x_label_angle):
            s.set_xticklabels(s.get_xticklabels(),rotation=75)
        
# 2. Subplot 2: Percentage of defaulters within the column
        
        s = sns.barplot(ax=ax2, x = col, y=target_col, data=target_1_percentage)
        ax2.set_title("Defaulters % in "+col, fontsize = 20)    
        ax2.set_xlabel(col,fontdict={'fontsize' : 15, 'fontweight' : 3})
        ax2.set_ylabel(target_col,fontdict={'fontsize' : 15, 'fontweight' : 3})
        
        if(x_label_angle):
            s.set_xticklabels(s.get_xticklabels(),rotation=75)
            
            
# If the plot is not readable, use the log scale
                
        if ylog:
            ax1.set_yscale('log')
            ax1.set_ylabel("Count (log)",fontdict={'fontsize' : 15, 'fontweight' : 3})
        else:
            ax1.set_ylabel("Count",fontdict={'fontsize' : 15, 'fontweight' : 3})

        
        plt.show()

# %%
# function for plotting repetitive rel plots in bivaritae numerical analysis

def bivariate_n(x,y,df,hue,kind,labels):
    plt.figure(figsize=[15,15])
    sns.relplot(x=x, y=y, data=df, hue=hue,kind=kind,legend = False)
    plt.legend(labels=labels)
    plt.xticks(rotation=45, ha='right')
    plt.show()

# %%
# function for plotting repetitive barplots in bivariate categorical analysis

def bivariate_c(x,y,df,hue,figsize,labels):
    
    plt.figure(figsize=figsize)
    sns.barplot(x=x,y=y,data=df, hue=hue)     
        
    # Defining aesthetics of Labels and Title of the plot using style dictionaries
    plt.xlabel(x,fontsize = 15)    
    plt.ylabel(y,fontsize = 15)    
    plt.title(col,fontsize = 20) 
    plt.xticks(rotation=45, ha='right')
    plt.legend(labels = labels )
    plt.show()

# %%
#function for plotting repetitive countplots in univariate categorical analysis on the merged df

def univariate_c_merged(col,df,hue,palette,ylog,figsize):
    plt.figure(figsize=figsize)
    ax=sns.countplot(x=col, data=df,hue= hue,palette= palette,order=df[col].value_counts().index)
    

    if ylog:
        plt.yscale('log')
        plt.ylabel("Count (log)",fontsize=15)     
    else:
        plt.ylabel("Count",fontsize=15)       

    plt.title(col , fontsize=20) 
    plt.legend(loc = "upper right")
    plt.xticks(rotation=45, ha='right')
    
    plt.show()

# %%
# Function to plot point plots 

def pointplot(df,hue,x,y):
    plt.figure(figsize=(12,6))
    sns.pointplot(x=x, y=y, hue=hue, data=df)
    plt.title(x+" VS "+y,fontsize = 15)

# %%
LoanData["loan_amnt"] = pd.to_numeric(LoanData["loan_amnt"])

# %%
LoanData["open_acc"] = pd.to_numeric(LoanData["open_acc"])

# %%
#1 Checking the contract type based on loan repayment status
univariate(LoanData,"loan_amnt","open_acc",False,False,True)

# %%
# checking the target columns unique values
LoanData['loan_status'].unique()
#array([0, 1])
# how columns are distributed in terms of categorical columns, purpose
sns.countplot(x="purpose", hue='loan_status', data=LoanData, palette="Set2")
# Out:
# <AxesSubplot:xlabel='purpose', ylabel='count'>

# %%
LoanData["open_acc"] = pd.to_numeric(LoanData["open_acc"])

# %%
LoanData["total_acc"] = pd.to_numeric(LoanData["total_acc"])

# %%
# Income type vs Income Amount Range on a Seaborn Barplot
bivariate_c('open_acc','total_acc',LoanData,"total_pymnt",(18,8),["open_acc","total_acc"])

# %%
# Plotting a percentage graph having each category of "loan_status"

plt.figure(figsize = [12,7])
(LoanData["loan_status"].value_counts()).plot.barh(color= "orange",width = .8)
plt.title("Percentage of loan status", fontdict={"fontsize":20}, pad =20)
plt.show()

# %% [markdown]
# # Correletion

# %%
# finding the correlations between the variables and displaying it
corr = LoanData.corr()
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
# Plotting a percentage graph having each category of "verification_status"

plt.figure(figsize = [12,7])
(LoanData["verification_status"].value_counts()).plot.barh(color= "Green",width = .8)
plt.title("Percentage of verification Status", fontdict={"fontsize":20}, pad =20)
plt.show()

# %% [markdown]
# # Conclusion

# %%
The percentage of Load Fully Paid is more compare to other and Not verified loan is more as per data analysis.
Loan with higher than 5000 is paid mostly by Account holders.
